# %% [markdown]
# ## Grover's algorithm on a 6-qubits space with the V-Oracle model

# %% [markdown]
# Search for the state |111111>

# %% [markdown]
# Import the required packages

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit import Aer, assemble
from qiskit.visualization import plot_histogram

# %% [markdown]
# Definine the registers

# %%
qreg_q = QuantumRegister(10, 'q')
creg_c = ClassicalRegister(6, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

# %% [markdown]
# Initialise the states

# %%
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.h(qreg_q[2])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.h(qreg_q[5])

# %% [markdown]
# Quantum barrier

# %%
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])

# %% [markdown]
# Iteration 1

# %% [markdown]
# V-oracle model

# %%
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.cz(qreg_q[9], qreg_q[5])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])

# %% [markdown]
# Quantum barrier

# %%
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])

# %% [markdown]
# Diffuser

# %%
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.h(qreg_q[2])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.h(qreg_q[5])
circuit.x(qreg_q[0])
circuit.x(qreg_q[1])
circuit.x(qreg_q[2])
circuit.x(qreg_q[3])
circuit.x(qreg_q[4])
circuit.x(qreg_q[5])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.cz(qreg_q[9], qreg_q[5])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.x(qreg_q[0])
circuit.x(qreg_q[1])
circuit.x(qreg_q[2])
circuit.x(qreg_q[3])
circuit.x(qreg_q[4])
circuit.x(qreg_q[5])
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.h(qreg_q[2])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.h(qreg_q[5])

# %% [markdown]
# Quantum barrier

# %%
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])

# %% [markdown]
# Iteration 2

# %%
# oracle iteration 2
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.cz(qreg_q[9], qreg_q[5])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
# barier
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])
# diffuser iteration 2
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.h(qreg_q[2])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.h(qreg_q[5])
circuit.x(qreg_q[0])
circuit.x(qreg_q[1])
circuit.x(qreg_q[2])
circuit.x(qreg_q[3])
circuit.x(qreg_q[4])
circuit.x(qreg_q[5])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.cz(qreg_q[9], qreg_q[5])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.x(qreg_q[0])
circuit.x(qreg_q[1])
circuit.x(qreg_q[2])
circuit.x(qreg_q[3])
circuit.x(qreg_q[4])
circuit.x(qreg_q[5])
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.h(qreg_q[2])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.h(qreg_q[5])
#barier *2
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])

# %% [markdown]
# Iteration 3

# %%
# oracle iteration 3
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.cz(qreg_q[9], qreg_q[5])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
# barier
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])
# diffuser iteration 3
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.h(qreg_q[2])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.h(qreg_q[5])
circuit.x(qreg_q[0])
circuit.x(qreg_q[1])
circuit.x(qreg_q[2])
circuit.x(qreg_q[3])
circuit.x(qreg_q[4])
circuit.x(qreg_q[5])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.cz(qreg_q[9], qreg_q[5])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.x(qreg_q[0])
circuit.x(qreg_q[1])
circuit.x(qreg_q[2])
circuit.x(qreg_q[3])
circuit.x(qreg_q[4])
circuit.x(qreg_q[5])
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.h(qreg_q[2])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.h(qreg_q[5])
#barier *2
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])

# %% [markdown]
# Iteration 4

# %%
# oracle iteration 4
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.cz(qreg_q[9], qreg_q[5])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
# barier
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])
# diffuser iteration 4
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.h(qreg_q[2])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.h(qreg_q[5])
circuit.x(qreg_q[0])
circuit.x(qreg_q[1])
circuit.x(qreg_q[2])
circuit.x(qreg_q[3])
circuit.x(qreg_q[4])
circuit.x(qreg_q[5])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.cz(qreg_q[9], qreg_q[5])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.x(qreg_q[0])
circuit.x(qreg_q[1])
circuit.x(qreg_q[2])
circuit.x(qreg_q[3])
circuit.x(qreg_q[4])
circuit.x(qreg_q[5])
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.h(qreg_q[2])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.h(qreg_q[5])
#barier *2
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])

# %% [markdown]
# Iteration 5

# %%
# oracle iteration 1
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.cz(qreg_q[9], qreg_q[5])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
# barier
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])
# diffuser iteration 1
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.h(qreg_q[2])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.h(qreg_q[5])
circuit.x(qreg_q[0])
circuit.x(qreg_q[1])
circuit.x(qreg_q[2])
circuit.x(qreg_q[3])
circuit.x(qreg_q[4])
circuit.x(qreg_q[5])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.cz(qreg_q[9], qreg_q[5])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.x(qreg_q[0])
circuit.x(qreg_q[1])
circuit.x(qreg_q[2])
circuit.x(qreg_q[3])
circuit.x(qreg_q[4])
circuit.x(qreg_q[5])
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.h(qreg_q[2])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.h(qreg_q[5])
#barier *2
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])

# %% [markdown]
# Iteration 6

# %%
# oracle iteration 6
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.cz(qreg_q[9], qreg_q[5])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
# barier
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])
# diffuser iteration 6
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.h(qreg_q[2])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.h(qreg_q[5])
circuit.x(qreg_q[0])
circuit.x(qreg_q[1])
circuit.x(qreg_q[2])
circuit.x(qreg_q[3])
circuit.x(qreg_q[4])
circuit.x(qreg_q[5])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.cz(qreg_q[9], qreg_q[5])
circuit.ccx(qreg_q[4], qreg_q[8], qreg_q[9])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])
circuit.ccx(qreg_q[2], qreg_q[3], qreg_q[7])
circuit.ccx(qreg_q[0], qreg_q[1], qreg_q[6])
circuit.x(qreg_q[0])
circuit.x(qreg_q[1])
circuit.x(qreg_q[2])
circuit.x(qreg_q[3])
circuit.x(qreg_q[4])
circuit.x(qreg_q[5])
circuit.h(qreg_q[0])
circuit.h(qreg_q[1])
circuit.h(qreg_q[2])
circuit.h(qreg_q[3])
circuit.h(qreg_q[4])
circuit.h(qreg_q[5])
#barier *2
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])
circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2], qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8], qreg_q[9])

# %% [markdown]
# Measurements

# %%
circuit.measure(qreg_q[0], creg_c[0])
circuit.measure(qreg_q[1], creg_c[1])
circuit.measure(qreg_q[2], creg_c[2])
circuit.measure(qreg_q[3], creg_c[3])
circuit.measure(qreg_q[4], creg_c[4])
circuit.measure(qreg_q[5], creg_c[5])

# %% [markdown]
# Simulation of the circuit

# %%
aer_sim = Aer.get_backend('aer_simulator')
qobj = assemble(circuit)
result = aer_sim.run(qobj).result()
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# Visualization of the circuit

# %%
circuit.draw(output="mpl")
